# %% [markdown]
# # SEARCH

# %%
# !python search.py

# %% [markdown]
# # TRAIN

# %%
# !python train.py \
--data_dir ../../input/kaggle \
--logdir ../../model/v5/trainablespec \
--seed 0 \
--batch_size 32 \
--infer_batch_size 16 \
--lr 5e-4 \
--weight_decay 0.01 \
--epochs 10 \
--encoder efficientnet_b0 \
--dropout 0.2 \
--num_workers 32 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 0 \
--gpu_numbers '0, 1, 2, 3' \
--win_seconds 10 \
--min_overlap_ratio 0.5 \
--default_label 0. \
--focal 0. \
--pos_weight 1. \
--aug 1 \
--mixup 0.5 \
--use_fp 1 \
--lsoft 0. \
--n_mels 32 \
--full 0 \
--lsep 1 \
--random_sample_prob 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 7218 | # Val Samples: 1779
# # Parameters: 8297558
# EPOCH: 0 | LRs: {1.9999999999999998e-05}
# 100%|█████████████████████████████████████████| 226/226 [01:51<00:00,  2.02it/s]
# 100%|█████████████████████████████████████████| 112/112 [00:52<00:00,  2.12it/s](trn) LOSS: 0.587236 ||
# (val) LOSS: 0.456264 | METRIC: 0.593481 || Runtime: 192
# EPOCH: 1 | LRs: {0.0004897741508381732}
# (trn) LOSS: 0.488401 || (val) LOSS: 0.453087 | METRIC: 0.596694 || Runtime: 183
# EPOCH: 2 | LRs: {0.00045572006360431133}
# (trn) LOSS: 0.430698 || (val) LOSS: 0.35146 | METRIC: 0.675184 || Runtime: 183
# EPOCH: 3 | LRs: {0.00040112333056016423}
# (trn) LOSS: 0.372529 || (val) LOSS: 0.299026 | METRIC: 0.741698 || Runtime: 184
# EPOCH: 4 | LRs: {0.0003314358594175124}
# (trn) LOSS: 0.337752 || (val) LOSS: 0.277327 | METRIC: 0.734902 || Runtime: 184
# EPOCH: 5 | LRs: {0.0002536164852595813}
# (trn) LOSS: 0.307863 || (val) LOSS: 0.229483 | METRIC: 0.814122 || Runtime: 185
# EPOCH: 6 | LRs: {0.00017543607682598023}
# (trn) LOSS: 0.268434 || (val) LOSS: 0.221329 | METRIC: 0.82197 || Runtime: 184
# EPOCH: 7 | LRs: {0.00010470155493200131}
# (trn) LOSS: 0.279316 || (val) LOSS: 0.208043 | METRIC: 0.829412 || Runtime: 185
# EPOCH: 8 | LRs: {4.847631080823453e-05}
# (trn) LOSS: 0.279049 || (val) LOSS: 0.225971 | METRIC: 0.815494 || Runtime: 185
# EPOCH: 9 | LRs: {1.2374871642364271e-05}
# (trn) LOSS: 0.246959 || (val) LOSS: 0.204712 | METRIC: 0.844548 || Runtime: 186
# Best Val Score: 0.8445482574978977
# Runtime: 1855

# %%
# !python train.py \
--data_dir ../../input/kaggle \
--logdir ../../model/v5/epoch20 \
--seed 0 \
--batch_size 32 \
--infer_batch_size 16 \
--lr 5e-4 \
--weight_decay 0.01 \
--epochs 20 \
--encoder efficientnet_b0 \
--dropout 0.2 \
--num_workers 32 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 0 \
--gpu_numbers '0, 1, 2, 3' \
--win_seconds 10 \
--min_overlap_ratio 0.5 \
--default_label 0. \
--focal 0. \
--pos_weight 1. \
--aug 1 \
--mixup 0.5 \
--use_fp 1 \
--lsoft 0. \
--n_mels 32 \
--full 0 \
--lsep 1 \
--random_sample_prob 0
# Out:
# Launched gpu 2
# Launched gpu 1
# Launched gpu 0
# Launched gpu 3
# # Train Samples: 7218 | # Val Samples: 1779
# # Parameters: 8297558
# EPOCH: 0 | LRs: {1.9999999999999998e-05}
# 100%|█████████████████████████████████████████| 226/226 [01:51<00:00,  2.03it/s]
# 100%|█████████████████████████████████████████| 112/112 [00:52<00:00,  2.12it/s](trn) LOSS: 0.606989 ||
# (val) LOSS: 0.624966 | METRIC: 0.407259 || Runtime: 191
# EPOCH: 1 | LRs: {0.0004979664312504048}
# (trn) LOSS: 0.497497 || (val) LOSS: 0.385528 | METRIC: 0.657669 || Runtime: 183
# EPOCH: 2 | LRs: {0.0004898237764778712}
# (trn) LOSS: 0.430088 || (val) LOSS: 0.372615 | METRIC: 0.669931 || Runtime: 183
# EPOCH: 3 | LRs: {0.00047565624051878797}
# (trn) LOSS: 0.419948 || (val) LOSS: 0.337588 | METRIC: 0.725696 || Runtime: 184
# EPOCH: 4 | LRs: {0.00045581974336588176}
# (trn) LOSS: 0.357608 || (val) LOSS: 0.258275 | METRIC: 0.782647 || Runtime: 184
# EPOCH: 5 | LRs: {0.0004308126219171686}
# (trn) LOSS: 0.343009 || (val) LOSS: 0.299778 | METRIC: 0.733943 || Runtime: 185
# EPOCH: 6 | LRs: {0.0004012631106454491}
# (trn) LOSS: 0.313198 || (val) LOSS: 0.293016 | METRIC: 0.769807 || Runtime: 185
# EPOCH: 7 | LRs: {0.0003679135589520074}
# (trn) LOSS: 0.303789 || (val) LOSS: 0.283094 | METRIC: 0.762476 || Runtime: 185
# EPOCH: 8 | LRs: {0.0003316017816996709}
# (trn) LOSS: 0.30359 || (val) LOSS: 0.256685 | METRIC: 0.788925 || Runtime: 185
# EPOCH: 9 | LRs: {0.00029324001144128884}
# (trn) LOSS: 0.266888 || (val) LOSS: 0.253306 | METRIC: 0.790924 || Runtime: 185
# EPOCH: 10 | LRs: {0.00025379198111043336}
# (trn) LOSS: 0.291719 || (val) LOSS: 0.264841 | METRIC: 0.766468 || Runtime: 186
# EPOCH: 11 | LRs: {0.00021424871290807028}
# (trn) LOSS: 0.243972 || (val) LOSS: 0.229923 | METRIC: 0.816462 || Runtime: 186
# EPOCH: 12 | LRs: {0.0001756036216221776}
# (trn) LOSS: 0.273725 || (val) LOSS: 0.230125 | METRIC: 0.802607 || Runtime: 186
# EPOCH: 13 | LRs: {0.00013882755784026143}
# (trn) LOSS: 0.235433 || (val) LOSS: 0.231575 | METRIC: 0.813273 || Runtime: 186
# EPOCH: 14 | LRs: {0.00010484441802473913}
# (trn) LOSS: 0.239318 || (val) LOSS: 0.230717 | METRIC: 0.826604 || Runtime: 186
# EPOCH: 15 | LRs: {7.450793418030741e-05}
# (trn) LOSS: 0.22814 || (val) LOSS: 0.223902 | METRIC: 0.816733 || Runtime: 187
# EPOCH: 16 | LRs: {4.858022620843971e-05}
# (trn) LOSS: 0.219404 || (val) LOSS: 0.211496 | METRIC: 0.844857 || Runtime: 185
# EPOCH: 17 | LRs: {2.7712655761537253e-05}
# (trn) LOSS: 0.24618 || (val) LOSS: 0.206395 | METRIC: 0.849836 || Runtime: 185
# EPOCH: 18 | LRs: {1.2429462590473433e-05}
# (trn) LOSS: 0.182913 || (val) LOSS: 0.20744 | METRIC: 0.837867 || Runtime: 187
# EPOCH: 19 | LRs: {3.114594476852006e-06}
# (trn) LOSS: 0.196164 || (val) LOSS: 0.205547 | METRIC: 0.844817 || Runtime: 186
# Best Val Score: 0.8498363214190552
# Runtime: 3720

# %%
# !python train.py \
--data_dir ../../input/kaggle \
--logdir ../../model/v5/bce \
--seed 0 \
--batch_size 32 \
--infer_batch_size 16 \
--lr 5e-4 \
--weight_decay 0.01 \
--epochs 10 \
--encoder efficientnet_b0 \
--dropout 0.2 \
--num_workers 32 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 0 \
--gpu_numbers '0, 1, 2, 3' \
--win_seconds 10 \
--min_overlap_ratio 0.5 \
--default_label 0. \
--focal 0. \
--pos_weight 1. \
--aug 1 \
--mixup 0.5 \
--use_fp 1 \
--lsoft 0. \
--n_mels 32 \
--full 0 \
--lsep 0 \
--random_sample_prob 0
# Out:
# Launched gpu 2
# Launched gpu 1
# Launched gpu 0
# Launched gpu 3
# # Train Samples: 7218 | # Val Samples: 1779
# # Parameters: 8297558
# EPOCH: 0 | LRs: {1.9999999999999998e-05}
# 100%|█████████████████████████████████████████| 226/226 [01:51<00:00,  2.03it/s]
# 100%|█████████████████████████████████████████| 112/112 [00:53<00:00,  2.10it/s](trn) LOSS: 0.093118 ||
# (val) LOSS: 0.049372 | METRIC: 0.444287 || Runtime: 192
# EPOCH: 1 | LRs: {0.0004897741508381732}
# (trn) LOSS: 0.044947 || (val) LOSS: 0.044294 | METRIC: 0.559691 || Runtime: 183
# EPOCH: 2 | LRs: {0.00045572006360431133}
# (trn) LOSS: 0.039793 || (val) LOSS: 0.042297 | METRIC: 0.599074 || Runtime: 183
# EPOCH: 3 | LRs: {0.00040112333056016423}
# (trn) LOSS: 0.038166 || (val) LOSS: 0.038358 | METRIC: 0.659022 || Runtime: 184
# EPOCH: 4 | LRs: {0.0003314358594175124}
# (trn) LOSS: 0.035123 || (val) LOSS: 0.036657 | METRIC: 0.733572 || Runtime: 184
# EPOCH: 5 | LRs: {0.0002536164852595813}
# (trn) LOSS: 0.031973 || (val) LOSS: 0.036038 | METRIC: 0.768107 || Runtime: 185
# EPOCH: 6 | LRs: {0.00017543607682598023}
# (trn) LOSS: 0.031038 || (val) LOSS: 0.034685 | METRIC: 0.786121 || Runtime: 185
# EPOCH: 7 | LRs: {0.00010470155493200131}
# (trn) LOSS: 0.029529 || (val) LOSS: 0.034225 | METRIC: 0.819737 || Runtime: 185
# EPOCH: 8 | LRs: {4.847631080823453e-05}
# (trn) LOSS: 0.029417 || (val) LOSS: 0.034587 | METRIC: 0.812553 || Runtime: 184
# EPOCH: 9 | LRs: {1.2374871642364271e-05}
# (trn) LOSS: 0.028472 || (val) LOSS: 0.033972 | METRIC: 0.827794 || Runtime: 186
# Best Val Score: 0.8277944677225253
# Runtime: 1856

# %%
# !python train.py \
--data_dir ../../input/kaggle \
--logdir ../../model/v5/bcelsoft0.7 \
--seed 0 \
--batch_size 32 \
--infer_batch_size 16 \
--lr 5e-4 \
--weight_decay 0.01 \
--epochs 10 \
--encoder efficientnet_b0 \
--dropout 0.2 \
--num_workers 32 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 0 \
--gpu_numbers '0, 1, 2, 3' \
--win_seconds 10 \
--min_overlap_ratio 0.5 \
--default_label 0. \
--focal 0. \
--pos_weight 1. \
--aug 1 \
--mixup 0.5 \
--use_fp 1 \
--lsoft 0.7 \
--n_mels 32 \
--full 0 \
--lsep 0 \
--random_sample_prob 0
# Out:
# Launched gpu 0
# Launched gpu 2
# Launched gpu 1
# Launched gpu 3
# # Train Samples: 7218 | # Val Samples: 1779
# # Parameters: 8297558
# EPOCH: 0 | LRs: {1.9999999999999998e-05}
# 100%|█████████████████████████████████████████| 226/226 [01:51<00:00,  2.02it/s]
# 100%|█████████████████████████████████████████| 112/112 [00:52<00:00,  2.12it/s](trn) LOSS: 0.145818 ||
# (val) LOSS: 0.050087 | METRIC: 0.522794 || Runtime: 193
# EPOCH: 1 | LRs: {0.0004897741508381732}
# (trn) LOSS: 0.084433 || (val) LOSS: 0.047436 | METRIC: 0.665844 || Runtime: 184
# EPOCH: 2 | LRs: {0.00045572006360431133}
# (trn) LOSS: 0.073607 || (val) LOSS: 0.044454 | METRIC: 0.664734 || Runtime: 183
# EPOCH: 3 | LRs: {0.00040112333056016423}
# (trn) LOSS: 0.07069 || (val) LOSS: 0.040245 | METRIC: 0.751201 || Runtime: 184
# EPOCH: 4 | LRs: {0.0003314358594175124}
# (trn) LOSS: 0.062782 || (val) LOSS: 0.036473 | METRIC: 0.768277 || Runtime: 184
# EPOCH: 5 | LRs: {0.0002536164852595813}
# (trn) LOSS: 0.061609 || (val) LOSS: 0.035487 | METRIC: 0.792912 || Runtime: 185
# EPOCH: 6 | LRs: {0.00017543607682598023}
# (trn) LOSS: 0.057357 || (val) LOSS: 0.034923 | METRIC: 0.793346 || Runtime: 185
# EPOCH: 7 | LRs: {0.00010470155493200131}
# (trn) LOSS: 0.056533 || (val) LOSS: 0.03252 | METRIC: 0.831964 || Runtime: 186
# EPOCH: 8 | LRs: {4.847631080823453e-05}
# (trn) LOSS: 0.056159 || (val) LOSS: 0.032813 | METRIC: 0.831297 || Runtime: 185
# EPOCH: 9 | LRs: {1.2374871642364271e-05}
# (trn) LOSS: 0.05511 || (val) LOSS: 0.032045 | METRIC: 0.835032 || Runtime: 186
# Best Val Score: 0.8350319744204636
# Runtime: 1857

# %% [markdown]
# # Infer

# %%
# !python infer.py \
--model_dir ../../model/final_models \
--out_dir . \
--infer_batch_size 16 \
--num_workers 16 \
--dataparallel 1 \
--slide_offset 10 \
--model_per_species 0 \
--full_clip 1
# Out:
# cuda
# ../../model/final_models/best.pth
# {'logdir': '../../model/v5/bcelsoft0.7', 'seed': 0, 'batch_size': 8, 'infer_batch_size': 4, 'lr': 0.0005, 'weight_decay': 0.01, 'epochs': 10, 'encoder': 'efficientnet_b0', 'win_seconds': 10, 'min_overlap_ratio': 0.5, 'default_label': 0.0, 'dropout': 0.2, 'num_workers': 8, 'fold': 0, 'data_frac': 1.0, 'amp': False, 'gpu_numbers': '0, 1, 2, 3', 'pretrained_path': None, 'data_dir': '../../input/kaggle', 'val_freq': 1, 'init_random': True, 'focal': 0.0, 'pos_weight': 1.0, 'aug': 1, 'pseudo_data_dir': None, 'n_fft': 2048, 'sr': 48000, 'hop_length': 256, 'n_mels': 32, 'mixup': 0.5, 'resume': 0, 'use_fp': 1, 'verbose': 1, 'species_id': None, 'uncertain_weight': 1.0, 'full': 0.0, 'lsoft': 0.7, 'lsep': 0, 'random_sample_prob': 0.0, 'fmin': 25, 'fmax': 15000}
# _IncompatibleKeys(missing_keys=['logmel_extractors.0.melW', 'logmel_extractors.1.melW', 'logmel_extractors.2.melW', 'logmel_extractors.3.melW', 'logmel_extractors.4.melW', 'logmel_extractors.5.melW', 'logmel_extractors.6.melW', 'logmel_extractors.7.melW', 'logmel_extractors.8.melW', 'logmel_extractors.9.melW', 'logmel_extractors.10.melW', 'logmel_extractors.11.melW', 'logmel_extractors.12.melW', 'logmel_extractors.13.melW', 'logmel_extractors.14.melW', 'logmel_extractors.15.melW', 'logmel_extractors.16.melW', 'logmel_extractors.17.melW', 'logmel_extractors.18.melW', 'logmel_extractors.19.melW', 'logmel_extractors.20.melW', 'logmel_extractors.21.melW', 'logmel_extractors.22.melW', 'logmel_extractors.23.melW'], unexpected_keys=[])
# 0.8350319744204636
#
# # uids: 1992
# 100%|█████████████████████████████████████████| 125/125 [00:51<00:00,  2.41it/s]
